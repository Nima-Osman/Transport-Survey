# %% [markdown]
# #Transportation system of wales
# This is the coding of the Transports data set provided

# %% [markdown]
# Relevant libraries are imported

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import os

# %%
import plotly as plt

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.patches as mpatches

# %% [markdown]
# The directory is listed.

# %%
os.listdir()
# Out:
# ['.config',
#  'Town.xlsx',
#  'Use of car.xlsx',
#  'Hospital.xlsx',
#  'Overall satisfaction.xlsx',
#  'Safety.xlsx',
#  'GP.xlsx',
#  'Age.xlsx',
#  'sample_data']

# %% [markdown]
# **The data for "Ease of getting too and from Hospital".**

# %%
df=pd.read_excel("Hospital.xlsx")

# %%
df
# Out:
#                                              Catogory  very easy  fairly easy  \
# 0         WIMD access to services: 20% most deprived   46.934796    33.535109
# 1   WIMD access to services: 20% - 40% most deprived   48.787299    33.374958
# 2    WIMD access to services: 20% - 60% most deprived  46.811278    35.563344
# 3    WIMD access to services: 20% -40% least deprived  48.009317    34.741961
# 4         WIMD access to services: 20% least deprived  47.859723    34.155558
# 5                            General health very good  62.120743    26.829465
# 6                                 General health Good  50.165877    34.455269
# 7                                 General health Fair  40.944140    38.541037
# 8                                  General health bad  30.690184    38.481386
# 9                             General health very bad  27.163567    39.484444
# 10                       Limiting long-term illnesses  35.286521    39.226812
# 11                    No limiting long-term illnesses  55.987276    30.975597
# 12                                    Have use of car  51.995591    33.944826
# 13                                 Have no use of car  30.847485    35.590879
# 14           Single pensioner (no children) household  34.800557    37.158473
# 15   Married couple pensioner (no children) household  44.045612    38.457220
# 16  Single person, not a pensioner (no children) h...  45.295981    33.375529
# 17       Two adult household with childeren household  56.388803    29.437471
# 18  Two adult household (up to one pensioner) with...  50.471980    33.743178
# 19                           Single parent household   53.179198    32.957824
# 20                                    Other household  44.474368    35.158951
# 21                           ACORN: Wealthy Achievers  52.624587    30.493725
# 22                            ACORN: Urban Prosperity  57.895798    28.830076
# 23                             ACORN: Comfortable Off  46.565815    35.675894
# 24                              ACORN: Moderate Means  43.030394    38.578358
# 25                                ACORN: Hard Pressed  44.236404    35.385506
# 26                                      In employment  56.379935    30.516308
# 27                           Not in employment status  40.383703    37.431630
# 28                                          Age:16-24  48.414281    34.381827
# 29                                         Age: 25-44  54.342385    30.910051
# 30                                         Age: 45-64  49.890344    33.283772
# 31                                         Age: 65-74  44.579864    36.697289
# 32                                   Age: 75 and over  34.173309    39.441224
# 33                                              Total  47.646578    34.290775
#
#     fairly difficult  very difficult
# 0          14.307299        5.222796
# 1          12.478565        5.359177
# 2          13.613482        4.011896
# 3          13.766975        3.481746
# 4          13.588902        4.395817
# 5           8.506253        2.543539
# 6          12.289022        3.089832
# 7          15.303422        5.211401
# 8          22.203302        8.625129
# 9          19.467771       13.884218
# 10         18.381308        7.105359
# 11         10.327918        2.709208
# 12         10.896750        3.162833
# 13         23.882832        9.678804
# 14         20.687722        7.353248
# 15         12.625185        4.871983
# 16         15.749548        5.578941
# 17         10.556055        3.617671
# 18         12.336961        3.447881
# 19          8.062286        6.000000
# 20         16.335126        5.000000
# 21         12.639063        4.242625
# 22         13.000000        0.000000
# 23         12.840471        4.917820
# 24         14.826084        3.565165
# 25         14.812622        5.565467
# 26          9.915637        3.188121
# 27         16.593294        5.591372
# 28         14.378012        4.000000
# 29         11.452472        3.295092
# 30         12.520736        4.305148
# 31         13.614386        5.108462
# 32         18.873219        7.512247
# 33         13.562137        4.500510

# %%
df.shape
# Out:
# (34, 5)

# %% [markdown]
# Description of the table

# %%
df.describe()
# Out:
#        very easy  fairly easy  fairly difficult  very difficult
# count  34.000000    34.000000         34.000000       34.000000
# mean   46.247756    34.561933         14.246906        5.004221
# std     8.294578     3.226963          3.649644        2.426699
# min    27.163567    26.829465          8.062286        0.000000
# 25%    43.284198    33.306568         12.372362        3.502601
# 50%    47.290687    34.418548         13.601192        4.686246
# 75%    51.614688    37.043177         15.638017        5.575573
# max    62.120743    39.484444         23.882832       13.884218

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Catogory          34 non-null     object
#  1   very easy         34 non-null     float64
#  2   fairly easy       34 non-null     float64
#  3   fairly difficult  34 non-null     float64
#  4   very difficult    34 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 1.5+ KB

# %% [markdown]
# Which categories have a very easy value of over and under 50%?

# %%
df.loc[df["very easy"]>50]
# Out:
#                                              Catogory  very easy  fairly easy  \
# 5                            General health very good  62.120743    26.829465
# 6                                 General health Good  50.165877    34.455269
# 11                    No limiting long-term illnesses  55.987276    30.975597
# 12                                    Have use of car  51.995591    33.944826
# 17       Two adult household with childeren household  56.388803    29.437471
# 18  Two adult household (up to one pensioner) with...  50.471980    33.743178
# 19                           Single parent household   53.179198    32.957824
# 21                           ACORN: Wealthy Achievers  52.624587    30.493725
# 22                            ACORN: Urban Prosperity  57.895798    28.830076
# 26                                      In employment  56.379935    30.516308
# 29                                         Age: 25-44  54.342385    30.910051
#
#     fairly difficult  very difficult
# 5           8.506253        2.543539
# 6          12.289022        3.089832
# 11         10.327918        2.709208
# 12         10.896750        3.162833
# 17         10.556055        3.617671
# 18         12.336961        3.447881
# 19          8.062286        6.000000
# 21         12.639063        4.242625
# 22         13.000000        0.000000
# 26          9.915637        3.188121
# 29         11.452472        3.295092

# %%
df.loc[df["very easy"]<50]
# Out:
#                                              Catogory  very easy  fairly easy  \
# 0         WIMD access to services: 20% most deprived   46.934796    33.535109
# 1   WIMD access to services: 20% - 40% most deprived   48.787299    33.374958
# 2    WIMD access to services: 20% - 60% most deprived  46.811278    35.563344
# 3    WIMD access to services: 20% -40% least deprived  48.009317    34.741961
# 4         WIMD access to services: 20% least deprived  47.859723    34.155558
# 7                                 General health Fair  40.944140    38.541037
# 8                                  General health bad  30.690184    38.481386
# 9                             General health very bad  27.163567    39.484444
# 10                       Limiting long-term illnesses  35.286521    39.226812
# 13                                 Have no use of car  30.847485    35.590879
# 14           Single pensioner (no children) household  34.800557    37.158473
# 15   Married couple pensioner (no children) household  44.045612    38.457220
# 16  Single person, not a pensioner (no children) h...  45.295981    33.375529
# 20                                    Other household  44.474368    35.158951
# 23                             ACORN: Comfortable Off  46.565815    35.675894
# 24                              ACORN: Moderate Means  43.030394    38.578358
# 25                                ACORN: Hard Pressed  44.236404    35.385506
# 27                           Not in employment status  40.383703    37.431630
# 28                                          Age:16-24  48.414281    34.381827
# 30                                         Age: 45-64  49.890344    33.283772
# 31                                         Age: 65-74  44.579864    36.697289
# 32                                   Age: 75 and over  34.173309    39.441224
# 33                                              Total  47.646578    34.290775
#
#     fairly difficult  very difficult
# 0          14.307299        5.222796
# 1          12.478565        5.359177
# 2          13.613482        4.011896
# 3          13.766975        3.481746
# 4          13.588902        4.395817
# 7          15.303422        5.211401
# 8          22.203302        8.625129
# 9          19.467771       13.884218
# 10         18.381308        7.105359
# 13         23.882832        9.678804
# 14         20.687722        7.353248
# 15         12.625185        4.871983
# 16         15.749548        5.578941
# 20         16.335126        5.000000
# 23         12.840471        4.917820
# 24         14.826084        3.565165
# 25         14.812622        5.565467
# 27         16.593294        5.591372
# 28         14.378012        4.000000
# 30         12.520736        4.305148
# 31         13.614386        5.108462
# 32         18.873219        7.512247
# 33         13.562137        4.500510

# %% [markdown]
# Creating a stackedbar chart to represent dataset

# %%
sns.set_theme(style="ticks")

# %%
#formatting the table
df.plot(kind="barh", stacked=True, color =["green", "yellow","orange", "red"],figsize=(15,15))
plt.yticks(list(range(0,34)),df["Catogory"].values)

#create label for x axis
plt.xlabel("score (%)")
#create label for y axis
plt.ylabel("category")
#legend title
plt.title("Ease of getting too and from Hospital")
# Out:
# Text(0.5, 1.0, 'Ease of getting too and from Hospital')

# %% [markdown]
# **Age VS Ease of access to Hospital**

# %%
df = pd.read_excel('Age.xlsx')

# %%
df
# Out:
#            category  Very easy
# 0         Age:16-24  48.414281
# 1        Age: 25-44  54.342385
# 2        Age: 45-64  49.890344
# 3        Age: 65-74  44.579864
# 4  Age: 75 and over  34.173309

# %%
import plotly.express as px
fig = px.scatter(df, x="category", y="Very easy")
fig.update_traces(marker_size=10)
fig.update_layout(scattermode="group")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8e86b769-5c8d-4abd-9fcc-e71771747cc0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e86b769-5c8d-4abd-9fcc-e71771747cc0")) {                    Plotly.newPlot(                        "8e86b769-5c8d-4abd-9fcc-e71771747cc0",                        [{"hovertemplate":"category=%{x}<br>Very easy=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","size":10},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["Age:16-24","Age: 25-44","Age: 45-64","Age: 65-74","Age: 75 and over"],"xaxis":"x","y":[48.414280741887,54.342384581529004,49.890344301542,44.579863720031,34.173309116675995],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{" ...

# %% [markdown]
# **Data from "Overall satisfaction with the Wales Transportation system."**

# %%
df = pd.read_excel('Overall satisfaction.xlsx')

# %%
df
# Out:
#                                          Satisfaction      Mean
# 0            Single pensioner (no children) household  6.230545
# 1    Married couple pensioner (no children) household  6.023997
# 2   Single person, not a pensioner (no children) h...  5.983174
# 3         Two adult household with children household  5.778549
# 4   Two adult household (up to one pensioner) with...  5.567446
# ..                                                ...       ...
# 65                    Feel safe after dark: Very safe  6.243695
# 66                  Feel safe after dark: Fairly safe  5.878821
# 67                Feel safe after dark: Fairly unsafe  5.496705
# 68                  Feel safe after dark: Very unsafe  5.674597
# 69                                              Total  5.883312
#
# [70 rows x 2 columns]

# %%
df.describe()
# Out:
#             Mean
# count  70.000000
# mean    5.879302
# std     0.301019
# min     5.241486
# 25%     5.703411
# 50%     5.900153
# 75%     6.079780
# max     6.495489

# %%
plt.figure(figsize=(20,15))
sns.barplot(x='Mean', y='Satisfaction', data=df.sort_values('Mean', ascending=False), color='b')
plt.title("Overall Satisfaction with state of transprotation system in Wales")
plt.xlabel("Mean Satisfaction")
plt.ylabel("Category")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df["Mean"], bins=10, kde=True)
# Out:
# <Axes: xlabel='Mean', ylabel='Count'>

# %%
df_selected = df[(df["Mean"]>=5.8)& (df["Mean"]<=6.1)]
df_selected
# Out:
#                                          Satisfaction      Mean
# 1    Married couple pensioner (no children) household  6.023997
# 2   Single person, not a pensioner (no children) h...  5.983174
# 5                            Single parent household   5.933492
# 9                                                Male  5.952226
# 10                                             Female  5.816476
# 11                                              Urban  6.016321
# 14                                            Gwynedd  5.986101
# 16                                       Denbighshire  6.079966
# 23                                            Swansea  5.848681
# 29                                     Merthyr Tydfil  6.079223
# 33                                      Monmouthshire  5.944389
# 34                                            Newport  5.894067
# 39          Cardiff and Vale public service footprint  5.955459
# 41           WIMD deprivation score:20% most deprived  6.057411
# 42    WIMD deprivation score: 20% - 40% most deprived  6.013204
# 43    WIMD deprivation score: 40% - 60% most deprived  5.805717
# 48  WIMD deprived of services: 40% - 60% most depr...  6.036093
# 49  WIMD deprived of services: 20% - 40% least dep...  6.018706
# 52       Medium or high (7-10) satisfaction with life  6.026518
# 54                                         Age: 25-44  5.906239
# 56                                         Age: 65-74  5.891244
# 61                      No limiting long term illness  5.937684
# 62                           Free from traffic: Agree  5.964537
# 63                        Free from traffic: Disagree  5.821301
# 66                  Feel safe after dark: Fairly safe  5.878821
# 69                                              Total  5.883312

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='Mean', y='Satisfaction', data=df_selected.sort_values('Mean', ascending=False), color='b')
plt.title("Overall Satisfaction with state of transport in Wales")
plt.xlabel("Mean Satisfaction")
plt.ylabel("Category")
plt.show()

# %%
df_selected.describe()
# Out:
#             Mean
# count  26.000000
# mean    5.952091
# std     0.080860
# min     5.805717
# 25%     5.891949
# 50%     5.953843
# 75%     6.018110
# max     6.079966

# %% [markdown]
# **Data from "ease of getting too and from GP".**

# %%
df=pd.read_excel("GP.xlsx")

# %%
df
# Out:
#                                              Category  very easy  fairly easy  \
# 0            WIMD deprivation score:20% most deprived  66.660920    27.387436
# 1     WIMD deprivation score: 20% - 40% most deprived  65.561175    28.587550
# 2     WIMD deprivation score: 40% - 60% most deprived  63.504870    30.221629
# 3    WIMD deprivation score: 20% - 40% least deprived  65.959825    26.585180
# 4          WIMD deprivation score: 20% least deprived  70.136070    23.220623
# 5                            General health very good  79.099944    18.339969
# 6                                 General health good  67.829995    27.624766
# 7                                 General health Fair  56.858330    34.110219
# 8                                  General health bad  41.318509    39.871705
# 9                             General health very bad  32.176047    40.419186
# 10                       Limiting long-term illnesses  49.399974    37.335110
# 11                    No limiting long-term illnesses  73.544917    22.944389
# 12                                    Have use of car  70.966208    25.225075
# 13                                 Have no use of car  48.082558    35.152033
# 14           Single pensioner (no children) household  46.718332    35.883829
# 15   Married couple pensioner (no children) household  60.539191    32.074252
# 16  Single person, not a pensioner (no children) h...  62.189869    29.235904
# 17       Two adult household with childeren household  73.228691    22.937286
# 18  Two adult household (up to one pensioner) with...  69.872401    25.944578
# 19                           Single parent household   63.180994    30.679007
# 20                                    Other household  69.736570    24.388946
# 21                           ACORN: Wealthy Achievers  70.350043    24.781132
# 22                            ACORN: Urban Prosperity  74.325715    21.111740
# 23                             ACORN: Comfortable Off  66.917123    27.855296
# 24                              ACORN: Moderate Means  63.612073    29.413781
# 25                                ACORN: Hard Pressed  60.704543    29.178230
# 26                                      In employment  75.674151    21.701823
# 27                           Not in employment status  56.655694    32.951318
# 28                                         Age: 16-24  71.779770    24.542490
# 29                                         Age: 25-44  72.559932    23.290840
# 30                                         Age: 45-64  68.009896    26.972709
# 31                                         Age: 65-74  61.671042    30.626518
# 32                                   Age: 75 and over  45.887962    36.472499
# 33                                              Total  66.331982    27.235409
#
#     fairly difficult  very difficult
# 0           4.327386        1.624258
# 1           3.748727        2.102548
# 2           4.663826        1.609675
# 3           5.619278        1.835718
# 4           4.659739        1.983568
# 5           2.070949        1.000000
# 6           3.471790        1.073450
# 7           7.012219        2.019231
# 8          11.740259        7.069528
# 9          11.263176       16.141591
# 10          8.700913        4.564004
# 11          2.844229        0.666464
# 12          3.016505        0.792213
# 13         10.858771        5.906637
# 14         11.875328        5.522511
# 15          5.016977        2.369580
# 16          4.948590        3.625638
# 17          3.175602        1.000000
# 18          3.042217        1.140804
# 19          5.042731        1.000000
# 20          4.366432        2.000000
# 21          3.597764        1.271061
# 22          5.000000        0.000000
# 23          3.652026        1.575556
# 24          4.869288        2.104858
# 25          7.382263        2.734964
# 26          2.181014        0.443012
# 27          7.125186        3.267802
# 28          3.126954        0.000000
# 29          3.184382        0.964846
# 30          3.666634        1.350762
# 31          5.008268        2.694173
# 32         11.942069        5.697470
# 33          4.604662        2.028788

# %%
df.shape
# Out:
# (34, 5)

# %%
df.describe()
# Out:
#        very easy  fairly easy  fairly difficult  very difficult
# count  34.000000    34.000000         34.000000       34.000000
# mean   63.266039    28.655955          5.494299        2.622962
# std    10.692122     5.459487          2.934934        2.947109
# min    32.176047    18.339969          2.070949        0.000000
# 25%    60.580529    24.602150          3.503283        1.018362
# 50%    66.145903    27.740031          4.661782        1.909643
# 75%    70.296550    31.725441          6.663984        2.724766
# max    79.099944    40.419186         11.942069       16.141591

# %%
#formatting the table
df.plot(kind="barh", stacked=True, color =["green", "yellow","orange", "red"], figsize=(15,15))

plt.yticks(list(range(0,34)), df["Category"].values)

#create label for x axis
plt.xlabel("score (%)")
#create label for y axis
plt.ylabel("category")
#legend title
plt.title("Ease of getting too and from GP")
# Out:
# Text(0.5, 1.0, 'Ease of getting too and from GP')

# %% [markdown]
# **Feeling of safety travelling using transportation systems**

# %%
#loading relevant data set
df = pd.read_excel("Safety.xlsx")

# %%
df
# Out:
#                                          Category  Very safe  Fairly safe  \
# 0                                      Age: 16-24  39.840065    44.676889
# 1                                      Age: 25-44  34.965828    46.843656
# 2                                      Age: 45-64  32.796650    46.903803
# 3                                      Age: 65-74  30.552904    45.093262
# 4                                Age: 75 and over  24.746321    40.885253
# 5                                            Male  43.211008    46.384843
# 6                                          Female  24.321936    45.131611
# 7       WIMD deprivation score: 20% most deprived  28.244607    44.465066
# 8    WIMD deprivation score: 20-40% most deprived  32.947223    44.997906
# 9    WIMD deprivation score: 40-60% most deprived  37.133631    43.996575
# 10  WIMD deprivation score: 20-40% least deprived  38.214005    43.853419
# 11     WIMD deprivation score: 20% least deprived  32.203332    51.236613
# 12                                          Total  33.583469    45.746085
#
#     Fairly unsafe  Very unsafe
# 0       12.100054     3.382992
# 1       13.787279     4.403237
# 2       15.493607     4.805941
# 3       16.612072     7.741762
# 4       22.732114    11.636312
# 5        8.556648     1.847502
# 6       21.644796     8.901656
# 7       18.860409     8.429919
# 8       16.417874     5.636996
# 9       13.561292     5.308502
# 10      14.382646     3.549930
# 11      12.567779     3.992275
# 12      15.227524     5.442922

# %%
df.describe()
# Out:
#        Very safe  Fairly safe  Fairly unsafe  Very unsafe
# count  13.000000    13.000000      13.000000    13.000000
# mean   33.289306    45.401152      15.534161     5.775381
# std     5.561427     2.344684       3.870840     2.700176
# min    24.321936    40.885253       8.556648     1.847502
# 25%    30.552904    44.465066      13.561292     3.992275
# 50%    32.947223    45.093262      15.227524     5.308502
# 75%    37.133631    46.384843      16.612072     7.741762
# max    43.211008    51.236613      22.732114    11.636312

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Category       13 non-null     object
#  1   Very safe      13 non-null     float64
#  2   Fairly safe    13 non-null     float64
#  3   Fairly unsafe  13 non-null     float64
#  4   Very unsafe    13 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 648.0+ bytes

# %%
df.shape
# Out:
# (13, 5)

# %%
df.describe()
# Out:
#        Very safe  Fairly safe  Fairly unsafe  Very unsafe
# count  13.000000    13.000000      13.000000    13.000000
# mean   33.289306    45.401152      15.534161     5.775381
# std     5.561427     2.344684       3.870840     2.700176
# min    24.321936    40.885253       8.556648     1.847502
# 25%    30.552904    44.465066      13.561292     3.992275
# 50%    32.947223    45.093262      15.227524     5.308502
# 75%    37.133631    46.384843      16.612072     7.741762
# max    43.211008    51.236613      22.732114    11.636312

# %%
#plotting data from table
f, axes = plt.subplots(2,2, figsize=(15,10))

sns.barplot(x='Very safe', y='Category', data=df, ax=axes[0,0], color='b')
sns.barplot(x='Fairly safe', y='Category', data=df, ax=axes[0,1], color='g')
sns.barplot(x='Fairly unsafe', y='Category', data=df, ax=axes[1,0], color='orange')
sns.barplot(x='Very unsafe', y='Category', data=df, ax=axes[1,1], color='r')

axes[0,0].set_title("Very safe", fontsize=14)
axes[0,1].set_title("Fairly safe", fontsize=14)
axes[1,0].set_title("Fairly unsafe", fontsize=14)
axes[1,1].set_title("Very unsafe", fontsize=14)

plt.suptitle("Feeling of safety travelling by public transport after dark", fontsize=20)
plt.tight_layout()

# %% [markdown]
# **Use of car**

# %%
df = pd.read_excel("Use of car.xlsx")

# %%
df
# Out:
#                                              Category        Yes         No
# 0                                                Male  81.702147  18.297853
# 1                                              Female  76.271586  23.728414
# 2                                               Urban  76.584410  23.415590
# 3                                               Rural  85.957959  14.042041
# 4            WIMD deprivation score:20% most deprived  64.770118  35.229882
# 5     WIMD deprivation score: 20% - 40% most deprived  74.820173  25.179827
# 6     WIMD deprivation score: 40% - 60% most deprived  81.233285  18.766715
# 7    WIMD deprivation score: 20% - 40% least deprived  85.684106  14.315894
# 8          WIMD deprivation score: 20% least deprived  88.747307  11.252693
# 9        WIMD deprived of services: 20% most deprived  88.753025  11.246975
# 10  WIMD deprived of services: 20% - 40% most depr...  83.459659  16.540341
# 11  WIMD deprived of services: 40% - 60% most depr...  79.194271  20.805729
# 12  WIMD deprived of services: 20% - 40% least dep...  73.949603  26.050397
# 13  WIMD deprived of services: 20% least deprived ...  68.903377  31.096623
# 14                                     In employement  90.326585   9.673415
# 15                                 Not in employement  66.056225  33.943775
# 16                       Limiting long-term illnesses  68.616592  31.383408
# 17                    No limiting long-term illnesses  82.346490  17.653510
# 18                                              Total  78.918266  21.081734

# %%
df.describe()
# Out:
#              Yes         No
# count  19.000000  19.000000
# mean   78.752378  21.247622
# std     7.781082   7.781082
# min    64.770118   9.673415
# 25%    74.384888  15.428117
# 50%    79.194271  20.805729
# 75%    84.571883  25.615112
# max    90.326585  35.229882

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  19 non-null     object
#  1   Yes       19 non-null     float64
#  2   No        19 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 584.0+ bytes

# %%
#formatting the table
df.plot(kind="barh", stacked=True, color =["green", "red"], figsize=(15,15))

plt.yticks(list(range(0,19)), df["Category"].values)

#create label for x axis
plt.xlabel("score (%)")
#create label for y axis
plt.ylabel("category")
#legend title
plt.title("Use of car")
# Out:
# Text(0.5, 1.0, 'Use of car')
